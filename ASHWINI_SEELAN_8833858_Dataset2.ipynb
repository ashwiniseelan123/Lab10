# %%
# !pip install pandas
import pandas as pd

# %%
df_AGV = pd.read_csv("C:/Users/ashwi/Assignment10/2019_ontario_public_library_statistics_open_data.csv", encoding='latin-1')

# %%
print(df_AGV.head())
# Out:
#          Library Full Name Library Number  Survey Year From  \
# 0  Addington Highlands Twp          L0005            2019.0
# 1     Adjala-TosorontioTwp          L0003            2019.0
# 2     Admaston/Bromley Twp          L0002            2019.0
# 3                     Ajax          L0032            2019.0
# 4             Alberton Twp          L1098            2019.0
#
#   A1.3 Ontario Library Service (OLS) Region (English)  \
# 0                   Southern Ontario Library Service
# 1                   Southern Ontario Library Service
# 2                   Southern Ontario Library Service
# 3                   Southern Ontario Library Service
# 4                    Ontario Library Service - North
#
#   A1.4 Type of Library Service (English)        A1.5 Mailing Address  \
# 0                Public or Union Library    3641 Flinton Rd. Box 72
# 1               Contracting Municipality   7855 Sideroad 30 R.R. #1
# 2                Public or Union Library         Hwy 60 P O Box 130
# ...

# %%
# Task-2.a
# Get the summary statistics of numerical columns
print("Summary statistics:\n {}".format(df_AGV.describe()))

# Get information about the dataset, including data types and missing values
print("Information about the dataset:\n {}".format(df_AGV.info()))
# Out:
# Summary statistics:
#         Survey Year From  C0.4.O  Other Special Collections - Original Format  \
# count             373.0                                         373.000000
# mean             2019.0                                           3.782842
# std                 0.0                                          50.670489
# min              2019.0                                           0.000000
# 25%              2019.0                                           0.000000
# 50%              2019.0                                           0.000000
# 75%              2019.0                                           0.000000
# max              2019.0                                         937.000000
#
#        C0.5.O  Other Special Collections - Digital Format  \
# count                                         373.000000
# mean                                            2.184987
# std                                            39.398578
# ...

# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Display the column names to check for the correct column names
print(df_AGV.columns)

# Check for any leading/trailing spaces in column names (optional)
print(df_AGV.columns.str.strip())

# Get the data types of the columns
print(df_AGV.dtypes)
# Out:
# Index(['Library Full Name', 'Library Number', 'Survey Year From',
#        'A1.3 Ontario Library Service (OLS) Region (English)',
#        'A1.4 Type of Library Service (English)', 'A1.5 Mailing Address',
#        'A1.9 Street Address', 'A1.10 City/Town', 'A1.11 Province',
#        'A1.12 Postal Code',
#        ...
#        'H1.9.1.T  Yes', 'H1.9.2.51  Chamber of Commerce',
#        'H1.9.2.52  Business Improvement Area (BIA)',
#        'H1.9.2.95  Other Business and Economic Sector Partnerships',
#        'H1.9.3  Please provide highlights or examples of your librarys partnerships with the business and economic sector:',
#        'P1.1  Resident Population Served',
#        'P1.2  Contracting Population Served',
#        'P2.1  Contracting Households Served',
#        'P2.2  Resident Households Served', 'Unnamed: 309'],
#       dtype='object', length=310)
# Index(['Library Full Name', 'Library Number', 'Survey Year From',
# ...

# %%
# Display the column names to check for the correct column name
print(df_AGV.columns)
# Out:
# Index(['Library Full Name', 'Library Number', 'Survey Year From',
#        'A1.3 Ontario Library Service (OLS) Region (English)',
#        'A1.4 Type of Library Service (English)', 'A1.5 Mailing Address',
#        'A1.9 Street Address', 'A1.10 City/Town', 'A1.11 Province',
#        'A1.12 Postal Code',
#        ...
#        'H1.9.1.T  Yes', 'H1.9.2.51  Chamber of Commerce',
#        'H1.9.2.52  Business Improvement Area (BIA)',
#        'H1.9.2.95  Other Business and Economic Sector Partnerships',
#        'H1.9.3  Please provide highlights or examples of your librarys partnerships with the business and economic sector:',
#        'P1.1  Resident Population Served',
#        'P1.2  Contracting Population Served',
#        'P2.1  Contracting Households Served',
#        'P2.2  Resident Households Served', 'Unnamed: 309'],
#       dtype='object', length=310)

# %%
# Display all column names
for column in df_AGV.columns:
    print(column)
# Out:
# Library Full Name
# Library Number
# Survey Year From
# A1.3 Ontario Library Service (OLS) Region (English)
# A1.4 Type of Library Service (English)
# A1.5 Mailing Address
# A1.9 Street Address
# A1.10 City/Town
# A1.11 Province
# A1.12 Postal Code
# A1.13 Web Site Address
# A1.14  No. of Active Library Cardholders
# B1.1  Net Balance brought forward from previous year
# B2.1.1  Public Library Operating Grant (PLOG)
# B2.1.2  Pay Equity Grant
# B2.1.3  First Nation Salary Supplement Grant
# B2.1.4  Total Provincial Operating Funding
# B2.2  Local Operating Funding (e.g. Municipality or Band local operating funding)
# B2.3  Contract Revenue (funds from other municipalities, neighbouring public library boards, Local Services Boards or First Nation Bands that contract for library services). Specify name of contracting organization and amount received from each.
# B2.4.1.03  Trillium Foundation funding
# B2.4.1.04  Provincial student employment funding
# B2.4.1.05  ServiceOntario
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Visualize the distribution of 'Total Annual Circulation'
sns.set(style='whitegrid')
sns.histplot(df_AGV['F1.0  Total Annual Circulation (Actual Annual Direct Circulation)'], bins=20, kde=True)
plt.title('Distribution of Total Annual Circulation')
plt.xlabel('Total Annual Circulation')
plt.show()

# Convert 'Total Annual Circulation' column to numeric
df_AGV['F1.0  Total Annual Circulation (Actual Annual Direct Circulation)'] = df_AGV['F1.0  Total Annual Circulation (Actual Annual Direct Circulation)'].str.replace(',', '').astype(float)

# Box plot of 'Total Annual Circulation'
sns.set(style='whitegrid')
sns.boxplot(x='F1.0  Total Annual Circulation (Actual Annual Direct Circulation)', data=df_AGV)
plt.title('Box Plot of Total Annual Circulation')
plt.xlabel('Total Annual Circulation')
plt.show()

# Scatter plot between 'Total Annual Circulation' and 'P1.1 Resident Population Served'
sns.scatterplot(x='F1.0  Total Annual Circulation (Actual Annual Direct Circulation)', y='P1.1  Resident Population Served', data=df_AGV)
plt.title('Scatter Plot: Total Annual Circulation vs. Resident Population Served')
plt.xlabel('Total Annual Circulation')
plt.ylabel('Resident Population Served')
plt.show()

# Count plot of 'A1.4 Type of Library Service (English)'
sns.countplot(x='A1.4 Type of Library Service (English)', data=df_AGV)
plt.title('Count Plot: Type of Library Service (English)')
plt.xlabel('Type of Library Service (English)')
plt.ylabel('Count')
plt.xticks(rotation=90)
plt.show()

# %%
pip install scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# task-3.a

import pandas as pd
from sklearn.preprocessing import StandardScaler, LabelEncoder

# Print data types of all columns in the DataFrame
print(df_AGV.dtypes)

# Identify columns with non-numeric data types
non_numeric_columns = df_AGV.select_dtypes(exclude=['float64', 'int64']).columns
print("Non-numeric columns:", non_numeric_columns)

# Handling missing values: Fill missing values in numerical columns with the mean value
numerical_columns = ['B1.1  Net Balance brought forward from previous year',
                     'B2.1.1  Public Library Operating Grant (PLOG)',
                     'B2.1.2  Pay Equity Grant'
                    ]

# Convert numerical columns to numeric type
df_AGV[numerical_columns] = df_AGV[numerical_columns].apply(pd.to_numeric, errors='coerce')

# Fill missing values with the mean of the respective column
for column in numerical_columns:
    mean_value = df_AGV[column].mean()
    df_AGV[column].fillna(mean_value, inplace=True)

# Drop non-numeric columns from numerical_columns
numerical_columns = [col for col in numerical_columns if df_AGV[col].dtype in ['float64', 'int64']]

# Normalize numerical features: Standardize numerical columns
if not df_AGV[numerical_columns].empty:
    scaler = StandardScaler()
    df_AGV[numerical_columns] = scaler.fit_transform(df_AGV[numerical_columns])

# Drop 'Unnamed: 309' column if it exists in the DataFrame
if 'Unnamed: 309' in df_AGV.columns:
    df_AGV.drop(['Unnamed: 309'], axis=1, inplace=True)

# Print the first few rows of the preprocessed DataFrame
print(df_AGV.head())

# Save the preprocessed DataFrame to a new CSV file (if needed)
df_AGV.to_csv("C:/Users/ashwi/Assignment10/preprocessed_2019_ontario_public_library_statistics_open_data.csv", index=False)
df_preprocessed_dataset_AGV = pd.read_csv("C:/Users/ashwi/Assignment10/preprocessed_2019_ontario_public_library_statistics_open_data.csv")
print(df_preprocessed_dataset_AGV.head())
# Out:
# Library Full Name                                       object
# Library Number                                          object
# Survey Year From                                       float64
# A1.3 Ontario Library Service (OLS) Region (English)     object
# A1.4 Type of Library Service (English)                  object
#                                                         ...
# P1.1  Resident Population Served                        object
# P1.2  Contracting Population Served                     object
# P2.1  Contracting Households Served                     object
# P2.2  Resident Households Served                        object
# Total Grants                                           float64
# Length: 310, dtype: object
# Non-numeric columns: Index(['Library Full Name', 'Library Number',
#        'A1.3 Ontario Library Service (OLS) Region (English)',
#        'A1.4 Type of Library Service (English)', 'A1.5 Mailing Address',
# ...

# %%
#task-3.b
import matplotlib.pyplot as plt

# Step 2: Handling Outliers
# Boxplots for numerical features
plt.figure(figsize=(12, 6))
df_AGV[numerical_columns].boxplot()
plt.title("Boxplot of Numerical Features")
plt.xticks(rotation=45)
plt.show()

# %%
# Assuming your DataFrame is named df_AGV
# Get the column names of the DataFrame
column_names = df_AGV.columns.tolist()

# Print the column names
print(column_names)
# Out:
# ['Library Full Name', 'Library Number', 'Survey Year From', 'A1.3 Ontario Library Service (OLS) Region (English)', 'A1.4 Type of Library Service (English)', 'A1.5 Mailing Address', 'A1.9 Street Address', 'A1.10 City/Town', 'A1.11 Province', 'A1.12 Postal Code', 'A1.13 Web Site Address', 'A1.14  No. of Active Library Cardholders', 'B1.1  Net Balance brought forward from previous year', 'B2.1.1  Public Library Operating Grant (PLOG)', 'B2.1.2  Pay Equity Grant', 'B2.1.3  First Nation Salary Supplement Grant', 'B2.1.4  Total Provincial Operating Funding', 'B2.2  Local Operating Funding (e.g. Municipality or Band local operating funding)', 'B2.3  Contract Revenue (funds from other municipalities, neighbouring public library boards, Local Services Boards or First Nation Bands that contract for library services). Specify name of contracting organization and amount received from each.', 'B2.4.1.03  Trillium Foundation funding', 'B2.4.1.04  Provincial student employment funding', 'B2.4.1.05 
# ...

# %%
#task 3
# Example of feature engineering: Creating a new feature 'Total Grants' by summing up the grant columns
df_AGV['Total Grants'] = df_AGV[['B2.1.1  Public Library Operating Grant (PLOG)', 'B2.1.2  Pay Equity Grant']].sum(axis=1)

print(df_AGV.head())
# Out:
#          Library Full Name Library Number  Survey Year From  \
# 0  Addington Highlands Twp          L0005            2019.0
# 1     Adjala-TosorontioTwp          L0003            2019.0
# 2     Admaston/Bromley Twp          L0002            2019.0
# 3                     Ajax          L0032            2019.0
# 4             Alberton Twp          L1098            2019.0
#
#   A1.3 Ontario Library Service (OLS) Region (English)  \
# 0                   Southern Ontario Library Service
# 1                   Southern Ontario Library Service
# 2                   Southern Ontario Library Service
# 3                   Southern Ontario Library Service
# 4                    Ontario Library Service - North
#
#   A1.4 Type of Library Service (English)        A1.5 Mailing Address  \
# 0                Public or Union Library    3641 Flinton Rd. Box 72
# 1               Contracting Municipality   7855 Sideroad 30 R.R. #1
# 2                Public or Union Library         Hwy 60 P O Box 130
# ...

# %%
#####task4.A
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.impute import SimpleImputer
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.multioutput import MultiOutputClassifier

# Assuming df_AGV contains the preprocessed DataFrame

# Define the feature columns (excluding the target column)
feature_columns = ['B1.1  Net Balance brought forward from previous year',
                   'B2.1.1  Public Library Operating Grant (PLOG)',
                   'B2.1.2  Pay Equity Grant'
                   ]

# Define the target column
target_column = ['F2.1.P  No. of programs held annually', 'F2.2.A  Annual program attendance']  # Replace 'Your_Target_Column_Name' with the actual column name

# Check for missing values in the feature columns
print(df_AGV[feature_columns].isnull().sum())

# Handle missing values in the feature columns using SimpleImputer
imputer = SimpleImputer(strategy='mean')  # You can use 'median' or 'most_frequent' as well
df_AGV[feature_columns] = imputer.fit_transform(df_AGV[feature_columns])

# Check for missing values in the target columns
print(df_AGV[target_column].isnull().sum())

# Fill missing values with 0
df_AGV[target_column] = df_AGV[target_column].fillna(0)

# Convert non-numeric values to numeric format (float) and replace ',' with ''
df_AGV[target_column] = df_AGV[target_column].apply(lambda x: pd.to_numeric(x.astype(str).str.replace(',', ''), errors='coerce'))

# Handle missing values in the target columns using SimpleImputer
target_imputer = SimpleImputer(strategy='mean')  # You can use 'median' or 'most_frequent' as well
df_AGV[target_column] = target_imputer.fit_transform(df_AGV[target_column])

# Split the data into training and testing sets
X = df_AGV[feature_columns]
y = df_AGV[target_column]

# Re-split the data with the same random state to ensure consistency
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Initialize the Random Forest Classifier
rf_classifier = RandomForestClassifier(random_state=42)

# Fit the model to the data
rf_classifier.fit(X_train, y_train)

# Initialize a list to store accuracy scores for each target column
rf_accuracy = []

# Get the predictions for all target columns
y_pred_all_columns = rf_classifier.predict(X_test)

# Evaluate accuracy score for each target column separately
for i, col in enumerate(y_test.columns):
    y_true_col = y_test[col]
    y_pred_col = y_pred_all_columns[:, i]  # Get the predictions for the specific target column
    accuracy_col = accuracy_score(y_true_col, y_pred_col)
    rf_accuracy.append(accuracy_col)

print("Random Forest Model Accuracy for each target column:")
print(pd.Series(rf_accuracy, index=y_test.columns))


# 2. Support Vector Machine (SVM) Model using MultiOutputClassifier
svm_classifier = MultiOutputClassifier(SVC(kernel='linear', C=1.0, random_state=42))
svm_classifier.fit(X_train, y_train)

# Make predictions using the SVM model
svm_predictions = svm_classifier.predict(X_test)

# Initialize a list to store accuracy scores for each target column
svm_accuracy = []

# Evaluate accuracy score for each target column separately
for i, col in enumerate(y_test.columns):
    y_true_col = y_test[col]
    y_pred_col = svm_predictions[:, i]  # Get the predictions for the specific target column
    accuracy_col = accuracy_score(y_true_col, y_pred_col)
    svm_accuracy.append(accuracy_col)

print("SVM Model Accuracy for each target column:")
print(pd.Series(svm_accuracy, index=y_test.columns))
# Out:
# B1.1  Net Balance brought forward from previous year    0
# B2.1.1  Public Library Operating Grant (PLOG)           0
# B2.1.2  Pay Equity Grant                                0
# dtype: int64
# F2.1.P  No. of programs held annually    0
# F2.2.A  Annual program attendance        0
# dtype: int64
# Random Forest Model Accuracy for each target column:
# F2.1.P  No. of programs held annually    0.230088
# F2.2.A  Annual program attendance        0.221239
# dtype: float64
# SVM Model Accuracy for each target column:
# F2.1.P  No. of programs held annually    0.230088
# F2.2.A  Annual program attendance        0.221239
# dtype: float64

# %%
#task4.B
from sklearn.metrics import precision_score, recall_score, f1_score
# 1. Random Forest Model Evaluation
print("Random Forest Model Evaluation:")

# Calculate accuracy for each target column separately
y_pred_rf = rf_classifier.predict(X_test)
for i, col in enumerate(y_test.columns):
    accuracy_col = accuracy_score(y_test[col], y_pred_rf[:, i])
    print(f"{col} - Accuracy: {accuracy_col:.3f}")

# Calculate precision, recall, and F1-score for each target column separately
for col in y_test.columns:
    y_true_col = y_test[col]
    y_pred_col = y_pred_rf[:, i]
    precision = precision_score(y_true_col, y_pred_col, average='weighted')
    recall = recall_score(y_true_col, y_pred_col, average='weighted')
    f1 = f1_score(y_true_col, y_pred_col, average='weighted')
    print(f"{col} - Precision: {precision:.3f}, Recall: {recall:.3f}, F1-score: {f1:.3f}")

# 2. Support Vector Machine (SVM) Model Evaluation
print("SVM Model Evaluation:")

# Calculate accuracy for each target column separately
for i, col in enumerate(y_test.columns):
    accuracy_col = accuracy_score(y_test[col], svm_predictions[:, i])
    print(f"{col} - Accuracy: {accuracy_col:.3f}")

# Calculate precision, recall, and F1-score for each target column separately
for col in y_test.columns:
    y_true_col = y_test[col]
    y_pred_col = svm_predictions[:, i]
    precision = precision_score(y_true_col, y_pred_col, average='weighted')
    recall = recall_score(y_true_col, y_pred_col, average='weighted')
    f1 = f1_score(y_true_col, y_pred_col, average='weighted')
    print(f"{col} - Precision: {precision:.3f}, Recall: {recall:.3f}, F1-score: {f1:.3f}")
# Out:
# Random Forest Model Evaluation:
# F2.1.P  No. of programs held annually - Accuracy: 0.230
# F2.2.A  Annual program attendance - Accuracy: 0.221
# F2.1.P  No. of programs held annually - Precision: 0.144, Recall: 0.221, F1-score: 0.174
# F2.2.A  Annual program attendance - Precision: 0.144, Recall: 0.221, F1-score: 0.174
# SVM Model Evaluation:
# F2.1.P  No. of programs held annually - Accuracy: 0.230
# F2.2.A  Annual program attendance - Accuracy: 0.221
# F2.1.P  No. of programs held annually - Precision: 0.059, Recall: 0.221, F1-score: 0.093
# F2.2.A  Annual program attendance - Precision: 0.059, Recall: 0.221, F1-score: 0.093
# C:\Users\ashwi\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming df_AGV is the DataFrame containing the first dataset
# Creating sample data
data_AGV = {
    'F2.1.P  No. of programs held annually': np.random.randint(5, 50, size=100),
    'F2.2.A  Annual program attendance': np.random.randint(100, 1000, size=100),
    'A1.11 Province': np.random.choice(['Ontario', 'Quebec', 'Alberta', 'British Columbia'], size=100),
}

df_AGV = pd.DataFrame(data_AGV)

# 1. Scatter Plot: Annual program attendance vs. No. of programs held annually
plt.figure(figsize=(8, 6))
sns.scatterplot(x='F2.1.P  No. of programs held annually', y='F2.2.A  Annual program attendance', data=df_AGV)
plt.title('Scatter Plot: Annual program attendance vs. No. of programs held annually')
plt.xlabel('No. of programs held annually')
plt.ylabel('Annual program attendance')
plt.show()

# 2. Bar Chart: Total Operating Revenues by Province (Sample column name used)
# Sample bar chart: Number of programs held annually by Province
programs_by_province = df_AGV.groupby('A1.11 Province')['F2.1.P  No. of programs held annually'].sum().reset_index()

plt.figure(figsize=(10, 6))
sns.barplot(x='A1.11 Province', y='F2.1.P  No. of programs held annually', data=programs_by_province)
plt.xlabel('Province')
plt.ylabel('Number of Programs Held Annually')
plt.title('Number of Programs Held Annually by Province')
plt.xticks(rotation=90)
plt.show()

# Sample bar chart: Annual program attendance by Province
attendance_by_province = df_AGV.groupby('A1.11 Province')['F2.2.A  Annual program attendance'].sum().reset_index()

plt.figure(figsize=(10, 6))
sns.barplot(x='A1.11 Province', y='F2.2.A  Annual program attendance', data=attendance_by_province)
plt.xlabel('Province')
plt.ylabel('Annual Program Attendance')
plt.title('Annual Program Attendance by Province')
plt.xticks(rotation=90)
plt.show()



# 3. Heatmap: Correlation Matrix between different attributes
# Assuming these are the numeric columns for correlation analysis
numeric_columns = ['F2.1.P  No. of programs held annually', 'F2.2.A  Annual program attendance']

# Selecting only the numeric columns from the DataFrame
numeric_df = df_AGV[numeric_columns]

# Calculate the correlation matrix for the numeric columns
correlation_matrix = numeric_df.corr()

# Plot the heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Matrix between Numeric Attributes')
plt.show()

# %%
# Print all the column names in the DataFrame
print(df_AGV.columns.tolist())
# Out:
# ['F2.1.P  No. of programs held annually', 'F2.2.A  Annual program attendance', 'A1.11 Province']

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming these are the numeric columns for the pairplot and boxplot
numeric_columns = ['F2.1.P  No. of programs held annually', 'F2.2.A  Annual program attendance']

# Pairplot: Visualize pairwise relationships between numeric attributes
sns.pairplot(df_AGV[numeric_columns])
plt.suptitle('Pairplot of Numeric Attributes', y=1.02)
plt.show()

# Boxplot: Visualize the distribution of 'F2.1.P  No. of programs held annually' and 'F2.2.A  Annual program attendance'
plt.figure(figsize=(8, 6))
sns.boxplot(data=df_AGV[numeric_columns], palette='Set3')
plt.title('Boxplot of Numeric Attributes')
plt.show()

# Bar Chart: Total number of programs held annually in each province
plt.figure(figsize=(10, 6))
sns.barplot(x='A1.11 Province', y='F2.1.P  No. of programs held annually', data=df_AGV, ci=None)
plt.title('Total Number of Programs Held Annually by Province')
plt.xlabel('Province')
plt.ylabel('Total Number of Programs')
plt.xticks(rotation=90)
plt.show()

# Violin Plot: Distribution of 'F2.2.A  Annual program attendance' in each province
plt.figure(figsize=(10, 6))
sns.violinplot(x='A1.11 Province', y='F2.2.A  Annual program attendance', data=df_AGV, palette='Pastel1')
plt.title('Distribution of Annual Program Attendance by Province')
plt.xlabel('Province')
plt.ylabel('Annual Program Attendance')
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\ashwi\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\ashwi\AppData\Local\Temp\ipykernel_2632\4202627085.py:20: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='A1.11 Province', y='F2.1.P  No. of programs held annually', data=df_AGV, ci=None)
